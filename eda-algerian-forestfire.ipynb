# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./Datasets/Algerian_forest_fires_dataset_UPDATE.csv',header=1)
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df.describe()
# Out:
#         day month  year Temperature   RH   Ws Rain   FFMC  DMC   DC  ISI  BUI  \
# count   246   245   245         245  245  245   245   245  245  245  245  245
# unique   33     5     2          20   63   19    40   174  167  199  107  175
# top      01    07  2012          35   64   14     0  88.9  7.9    8  1.1    3
# freq      8    62   244          29   10   43   133     8    5    5    8    5
#
#         FWI Classes
# count   245       244
# unique  128         9
# top     0.4   fire
# freq     12       131

# %%
columns=df.columns.to_list

# %%
columns
# Out:
# <bound method IndexOpsMixin.tolist of Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')>

# %%
[features for features in df.columns if df[features].isnull().sum()>1 ]
# Out:
# ['Classes  ']

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.loc[:122,'Region']=1
df.loc[122:,'Region']=2
df[['Region']] = df[['Region']].astype(int)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          1
# ...

# %%
df.isna().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          1
# ...

# %%
df1=df[df['Region']==1]

# %%
df1
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 117  26    09  2012          31  54  11     0    82    6  16.3  2.5  6.2  1.7
# 118  27    09  2012          31  66  11     0  85.7  8.3  24.9    4    9  4.1
# 119  28    09  2012          32  47  14   0.7  77.5  7.1   8.8  1.8  6.8  0.9
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
#
#        Classes    Region
# ...

# %%
df2=df[df['Region']==2]

# %%
df2.reset_index(drop=True)
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  \
# 0    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI
# 1     01     06  2012           32   71   12    0.7  57.1  2.5   8.2  0.6
# 2     02     06  2012           30   73   13      4  55.7  2.7   7.8  0.6
# 3     03     06  2012           29   80   14      2  48.7  2.2   7.6  0.3
# 4     04     06  2012           30   64   14      0  79.4  5.2  15.4  2.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 117   26     09  2012           30   65   14      0  85.4   16  44.5  4.5
# 118   27     09  2012           28   87   15    4.4  41.1  6.5     8  0.1
# 119   28     09  2012           27   87   29    0.5  45.9  3.5   7.9  0.4
# 120   29     09  2012           24   54   18    0.1  79.7  4.3  15.2  1.7
# 121   30     09  2012           24   64   15    0.2  67.3  3.8  16.5  1.2
#
#       BUI  FWI     Classes    Region
# 0     BUI  FWI     Classes         2
# ...

# %%
df2=df2.iloc[1:]

# %%
df2
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 124  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6   2.8
# 125  02    06  2012          30  73  13     4  55.7  2.7   7.8  0.6   2.9
# 126  03    06  2012          29  80  14     2  48.7  2.2   7.6  0.3   2.6
# 127  04    06  2012          30  64  14     0  79.4  5.2  15.4  2.2   5.6
# 128  05    06  2012          32  60  14   0.2  77.1    6  17.6  1.8   6.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 124  0.2   not fire          2
# ...

# %%
df=pd.concat([df1,df2])

# %%
df[120:130]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3     3
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2   2.4
# 124  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6   2.8
# 125  02    06  2012          30  73  13     4  55.7  2.7   7.8  0.6   2.9
# 126  03    06  2012          29  80  14     2  48.7  2.2   7.6  0.3   2.6
# 127  04    06  2012          30  64  14     0  79.4  5.2  15.4  2.2   5.6
# 128  05    06  2012          32  60  14   0.2  77.1    6  17.6  1.8   6.5
# 129  06    06  2012          35  54  11   0.1  83.7  8.4  26.3  3.1   9.3
# 130  07    06  2012          35  44  17   0.2  85.6  9.9  28.9  5.4  10.7
# 131  08    06  2012          28  51  17   1.3  71.4  7.7   7.4  1.5   7.3
#
#      FWI    Classes    Region
# 120  0.1  not fire          1
# 121  0.1  not fire          1
# 124  0.2  not fire          2
# ...

# %%
df=df.reset_index(drop=True)

# %%
df[120:130]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3     3
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2   2.4
# 122  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6   2.8
# 123  02    06  2012          30  73  13     4  55.7  2.7   7.8  0.6   2.9
# 124  03    06  2012          29  80  14     2  48.7  2.2   7.6  0.3   2.6
# 125  04    06  2012          30  64  14     0  79.4  5.2  15.4  2.2   5.6
# 126  05    06  2012          32  60  14   0.2  77.1    6  17.6  1.8   6.5
# 127  06    06  2012          35  54  11   0.1  83.7  8.4  26.3  3.1   9.3
# 128  07    06  2012          35  44  17   0.2  85.6  9.9  28.9  5.4  10.7
# 129  08    06  2012          28  51  17   1.3  71.4  7.7   7.4  1.5   7.3
#
#      FWI    Classes    Region
# 120  0.1  not fire          1
# 121  0.1  not fire          1
# 122  0.2  not fire          2
# ...

# %%
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df[['month', 'day', 'year', 'Temperature','RH', 'Ws']] = df[['month', 'day', 'year', 'Temperature','RH', 'Ws']].astype(int)

# %%
objects = [features for features in df.columns if df[features].dtypes=='O']
for i in objects:
    if i!='Classes':
        df[i]=df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.0+ KB

# %%
df.shape
# Out:
# (243, 15)

# %%
df.describe().T
# Out:
#              count         mean        std     min      25%     50%      75%  \
# day          243.0    15.761317   8.842552     1.0     8.00    16.0    23.00
# month        243.0     7.502058   1.114793     6.0     7.00     8.0     8.00
# year         243.0  2012.000000   0.000000  2012.0  2012.00  2012.0  2012.00
# Temperature  243.0    32.152263   3.628039    22.0    30.00    32.0    35.00
# RH           243.0    62.041152  14.828160    21.0    52.50    63.0    73.50
# Ws           243.0    15.493827   2.811385     6.0    14.00    15.0    17.00
# Rain         243.0     0.762963   2.003207     0.0     0.00     0.0     0.50
# FFMC         243.0    77.842387  14.349641    28.6    71.85    83.3    88.30
# DMC          243.0    14.680658  12.393040     0.7     5.80    11.3    20.80
# DC           243.0    49.430864  47.665606     6.9    12.35    33.1    69.10
# ISI          243.0     4.742387   4.154234     0.0     1.40     3.5     7.25
# ...

# %%
df.to_csv('./Datasets/Algerian_Forest_Fire_cleaned.csv',index=False)

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df['Classes']=df['Classes'].str.strip()

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire        137
# not fire    106
# Name: count, dtype: int64

# %% [markdown]
# ## Bejaia Region up to 122

# %%
df[:122]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1      2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2      3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4      5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...  ...   ...  ...  ...
# 117   26      9  2012           31  54  11   0.0  82.0  6.0  16.3  2.5  6.2
# 118   27      9  2012           31  66  11   0.0  85.7  8.3  24.9  4.0  9.0
# 119   28      9  2012           32  47  14   0.7  77.5  7.1   8.8  1.8  6.8
# 120   29      9  2012           26  80  16   1.8  47.4  2.9   7.7  0.3  3.0
# 121   30      9  2012           25  78  14   1.4  45.0  1.9   7.5  0.2  2.4
#
#      FWI   Classes  Region
# 0    0.5  not fire       1
# ...

# %% [markdown]
# ## Sidi-Bel Abbes Region after 122

# %%
df[122:]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 124    1      6  2012           32  71  12   0.7  57.1   2.5   8.2  0.6   2.8
# 125    2      6  2012           30  73  13   4.0  55.7   2.7   7.8  0.6   2.9
# 126    3      6  2012           29  80  14   2.0  48.7   2.2   7.6  0.3   2.6
# 127    4      6  2012           30  64  14   0.0  79.4   5.2  15.4  2.2   5.6
# 128    5      6  2012           32  60  14   0.2  77.1   6.0  17.6  1.8   6.5
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 241   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 242   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 243   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 244   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 245   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# ...

# %%
#Droping Year features
df1 = df.drop(['day','month','year'], axis=1)
df1
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI   Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5  not fire
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4  not fire
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1  not fire
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0  not fire
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5  not fire
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...       ...
# 241           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5      fire
# 242           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0  not fire
# 243           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2  not fire
# 244           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7  not fire
# 245           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5  not fire
#
#      Region
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
df['month'].value_counts()
# Out:
# month
# 8    62
# 7    61
# 6    60
# 9    60
# Name: count, dtype: int64

# %%
plt.style.use('seaborn')
df1.hist(bins=50, figsize=(20,15), ec = 'b')

plt.show()
# Out:
# C:\Users\Arushi Prajapati\AppData\Local\Temp\ipykernel_18388\2920518116.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
sns.countplot(x=df['month'],hue=df['Classes'],palette= 'Set2',ec='black',data=df)
plt.xticks(np.arange(4), ['June','July', 'August', 'September',])
plt.show()

# %%
dftemp1= df.loc[df['Region']== 1]
dftemp2= df.loc[df['Region']== 2]

# %%
dftemp2
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 124    1      6  2012           32  71  12   0.7  57.1   2.5   8.2  0.6   2.8
# 125    2      6  2012           30  73  13   4.0  55.7   2.7   7.8  0.6   2.9
# 126    3      6  2012           29  80  14   2.0  48.7   2.2   7.6  0.3   2.6
# 127    4      6  2012           30  64  14   0.0  79.4   5.2  15.4  2.2   5.6
# 128    5      6  2012           32  60  14   0.2  77.1   6.0  17.6  1.8   6.5
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 241   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 242   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 243   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 244   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 245   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# ...

# %%
sns.countplot(x=dftemp1['month'],hue=dftemp1['Classes'],palette= 'Set2',ec='black',data=dftemp1)
plt.xticks(np.arange(4), ['June','July', 'August', 'September',])
plt.show()

# %%
sns.countplot(x=dftemp2['month'],hue=dftemp2['Classes'],palette= 'Set2',ec='black',data=dftemp2)
plt.xticks(np.arange(4), ['June','July', 'August', 'September',])
plt.show()

# %% [markdown]
# ## EDA

# %%
df=df.drop(['day','month','year'], axis=1)
df
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI   Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5  not fire
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4  not fire
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1  not fire
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0  not fire
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5  not fire
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...       ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5      fire
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0  not fire
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2  not fire
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7  not fire
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5  not fire
#
#      Region
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire        137
# not fire    106
# Name: count, dtype: int64

# %%
df['Classes']=np.where(df['Classes']=='fire',1,0)

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr().T,annot=True)
# plt.show()
# Out:
# <Axes: >

# %%
df.to_csv('./Datasets/Algerian_Forest_Fire_cleaned.csv',index=False)
